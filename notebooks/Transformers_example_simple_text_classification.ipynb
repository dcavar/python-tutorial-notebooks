# %% [markdown]
# # Transformer Implementation Example for Text Classification
#
# **(C) 2024-2025 by [Damir Cavar](http://damir.cavar.me/)**
#
#
# **Download:** This and various other Jupyter notebooks are available from my [GitHub repo](https://github.com/dcavar/python-tutorial-for-ipython).
#
#
# Based on [Transformer Text Classification by Eijaz Allibhai](https://github.com/jaz-alli/transformers-text-classification/blob/main/transformers_text_classification.ipynb).

# %%
# !pip install transformers

# %% [markdown]
# Import the `transformer` pipeline:

# %%
from transformers import pipeline
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/.local/lib/python3.13/site-packages/transformers/utils/import_utils.py:2317, in _LazyModule.__getattr__(self, name)
#    2316 try:
# -> 2317     module = self._get_module(self._class_to_module[name])
#    2318     value = getattr(module, name)
#
# File ~/.local/lib/python3.13/site-packages/transformers/utils/import_utils.py:2347, in _LazyModule._get_module(self, module_name)
#    2346 except Exception as e:
# -> 2347     raise e
#
# File ~/.local/lib/python3.13/site-packages/transformers/utils/import_utils.py:2345, in _LazyModule._get_module(self, module_name)
#    2344 try:
# -> 2345     return importlib.import_module("." + module_name, self.__name__)
#    2346 except Exception as e:
#
# File /usr/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:1026, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~/.local/lib/python3.13/site-packages/transformers/pipelines/__init__.py:26
#      25 from ..feature_extraction_utils import PreTrainedFeatureExtractor
# ---> 26 from ..image_processing_utils import BaseImageProcessor
#      27 from ..models.auto.configuration_auto import AutoConfig
#
# File ~/.local/lib/python3.13/site-packages/transformers/image_processing_utils.py:21
#      19 import numpy as np
# ---> 21 from .image_processing_base import BatchFeature, ImageProcessingMixin
#      22 from .image_transforms import center_crop, normalize, rescale
#
# File ~/.local/lib/python3.13/site-packages/transformers/image_processing_base.py:26
#      25 from .feature_extraction_utils import BatchFeature as BaseBatchFeature
# ---> 26 from .image_utils import is_valid_image, load_image
#      27 from .utils import (
#      28     IMAGE_PROCESSOR_NAME,
#      29     PROCESSOR_NAME,
#    (...)
#      35     logging,
#      36 )
#
# File ~/.local/lib/python3.13/site-packages/transformers/image_utils.py:55
#      54 if is_torchvision_available():
# ---> 55     from torchvision.transforms import InterpolationMode
#      57     pil_torch_interpolation_mapping = {
#      58         PILImageResampling.NEAREST: InterpolationMode.NEAREST_EXACT,
#      59         PILImageResampling.BOX: InterpolationMode.BOX,
#    (...)
#      63         PILImageResampling.LANCZOS: InterpolationMode.LANCZOS,
#      64     }
#
# File /usr/lib/python3/dist-packages/torchvision/__init__.py:10
#       9 from .extension import _HAS_OPS  # usort:skip
# ---> 10 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils  # usort:skip
#      12 try:
#
# File /usr/lib/python3/dist-packages/torchvision/_meta_registrations.py:163
#     160     return grad.new_empty((batch_size, channels, height, width))
# --> 163 @torch.library.register_fake("torchvision::nms")
#     164 def meta_nms(dets, scores, iou_threshold):
#     165     torch._check(dets.dim() == 2, lambda: f"boxes should be a 2d tensor, got {dets.dim()}D")
#
# File ~/.local/lib/python3.13/site-packages/torch/library.py:1069, in register_fake.<locals>.register(func)
#    1068     use_lib = lib
# -> 1069 use_lib._register_fake(
#    1070     op_name, func, _stacklevel=stacklevel + 1, allow_override=allow_override
#    1071 )
#    1072 return func
#
# File ~/.local/lib/python3.13/site-packages/torch/library.py:219, in Library._register_fake(self, op_name, fn, _stacklevel, allow_override)
#     217     func_to_register = fn
# --> 219 handle = entry.fake_impl.register(
#     220     func_to_register, source, lib=self, allow_override=allow_override
#     221 )
#     222 self._registration_handles.append(handle)
#
# File ~/.local/lib/python3.13/site-packages/torch/_library/fake_impl.py:50, in FakeImplHolder.register(self, func, source, lib, allow_override)
#      45     raise RuntimeError(
#      46         f"register_fake(...): the operator {self.qualname} "
#      47         f"already has an fake impl registered at "
#      48         f"{self.kernel.source}."
#      49     )
# ---> 50 if torch._C._dispatch_has_kernel_for_dispatch_key(self.qualname, "Meta"):
#      51     raise RuntimeError(
#      52         f"register_fake(...): the operator {self.qualname} "
#      53         f"already has an DispatchKey::Meta implementation via a "
#    (...)
#      56         f"register_fake."
#      57     )
#
# RuntimeError: operator torchvision::nms does not exist
#
# The above exception was the direct cause of the following exception:
#
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from transformers import pipeline
#
# File ~/.local/lib/python3.13/site-packages/transformers/utils/import_utils.py:2320, in _LazyModule.__getattr__(self, name)
#    2318         value = getattr(module, name)
#    2319     except (ModuleNotFoundError, RuntimeError) as e:
# -> 2320         raise ModuleNotFoundError(
#    2321             f"Could not import module '{name}'. Are this object's requirements defined correctly?"
#    2322         ) from e
#    2324 elif name in self._modules:
#    2325     try:
#
# ModuleNotFoundError: Could not import module 'pipeline'. Are this object's requirements defined correctly?

# %% [markdown]
# See the [documentation for the pipeline](https://huggingface.co/docs/transformers/en/main_classes/pipelines) on the website.

# %% [markdown]
# In the following we use the zero-shot-classification approach. This is predicting a class for some text that wasn't seen by the model during training. The pre-trained language model is used in that task without tuning or additional training.

# %% [markdown]
# Setting the device parameter to 0 will activate GPU-based processing, which might improve the processing time:
#
#     classifier = pipeline("zero-shot-classification", device=0)

# %%
classifier = pipeline("zero-shot-classification", model="facebook/bart-large-mnli")
# Out:
# c:\Users\damir\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %% [markdown]
# We can specify some text and potential labels (or keywords) for it:

# %%
sequence = "I was preparing a pizza for dinner."
labels = ["cooking", "dancing", "singing", "sleeping"]

# %% [markdown]
# The `classifier` will generate a list of labels and a list of scores. The scores in this case sum up to 1 and represent probabilities.

# %%
classifier(sequence, labels)
# Out:
# {'sequence': 'I was preparing a pizza for dinner.',
#  'labels': ['cooking', 'dancing', 'singing', 'sleeping'],
#  'scores': [0.9980718493461609,
#   0.0006987973465584219,
#   0.000633605697657913,
#   0.000595774850808084]}

# %% [markdown]
# We can also specify a list of texts to label using the model:

# %%
sequences = ["An increase in travel demand is one of the causes of an oil price increase",
            "As expected, polls show that the party in power will lose seats in Congress during the midterm elections.",
            "The party in power may lose seats in the next election due to inflation and recession concerns"]

# %% [markdown]
# The `classifier` will return a list of text, label, and score tuples.

# %%
classifier(sequences, labels)
# Out:
# [{'sequence': 'An increase in travel demand is one of the causes of an oil price increase',
#   'labels': ['dancing', 'cooking', 'singing', 'sleeping'],
#   'scores': [0.2957216501235962,
#    0.2929859459400177,
#    0.2571319341659546,
#    0.15416045486927032]},
#  {'sequence': 'As expected, polls show that the party in power will lose seats in Congress during the midterm elections.',
#   'labels': ['singing', 'cooking', 'dancing', 'sleeping'],
#   'scores': [0.3710725009441376,
#    0.3375093638896942,
#    0.16009816527366638,
#    0.13131999969482422]},
#  {'sequence': 'The party in power may lose seats in the next election due to inflation and recession concerns',
#   'labels': ['singing', 'cooking', 'dancing', 'sleeping'],
#   'scores': [0.36309170722961426,
#    0.2650962173938751,
#    0.203884094953537,
#    0.16792798042297363]}]

# %% [markdown]
# It is also possible to use multi-labels for the text, i.e., each label receives a score for how goot it fits the corresponding text. The user needs to specify a threshold of exclusion based on the scores.

# %%
classifier(sequences, labels, multi_label=True)
# Out:
# [{'sequence': 'An increase in travel demand is one of the causes of an oil price increase',
#   'labels': ['automotive', 'economy', 'programming', 'politics'],
#   'scores': [0.009671766310930252,
#    0.0009950732346624136,
#    0.00010522549564484507,
#    4.6886860218364745e-05]},
#  {'sequence': 'As expected, polls show that the party in power will lose seats in Congress during the midterm elections.',
#   'labels': ['politics', 'economy', 'programming', 'automotive'],
#   'scores': [0.9895076751708984,
#    0.443315714597702,
#    0.09925836324691772,
#    0.04091533273458481]},
#  {'sequence': 'The party in power may lose seats in the next election due to inflation and recession concerns',
#   'labels': ['politics', 'economy', 'programming', 'automotive'],
#   'scores': [0.9844666719436646,
#    0.9779921174049377,
#    0.009205055423080921,
#    0.0031888692174106836]}]

# %% [markdown]
# (C) 2024-2025 by [Damir Cavar](http://damir.cavar.me/)
