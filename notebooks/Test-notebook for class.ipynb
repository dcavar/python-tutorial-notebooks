# %% [markdown]
# # Test

# %% [markdown]
# Type some text here...

# %% [markdown]
# I want to compute the equation $\sum_{i=0}^{10} i * 2$:

# %%
res = 0
for i in range(11):
    res = res + i * 4
print(res)
# Out:
# 220
